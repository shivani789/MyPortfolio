# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani789/MyPortfolio/blob/master/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt 
print(cv2.__version__)
image = cv2.imread('img.jpg', 0)
#cv2.imshow('cutiii', image)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()
# Out:
# 4.1.2
